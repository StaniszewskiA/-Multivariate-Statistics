# %%
energy_data <- read.csv("energy_dataset_.csv")
head(energy_data)
# Out:
#   Type_of_Renewable_Energy Installed_Capacity_MW Energy_Production_MWh
# 1 4                         93.42321             103853.2
# 2 4                        590.46894             190223.1
# 3 1                        625.95114             266023.5
# 4 1                        779.99873             487039.5
# 5 3                        242.10684             482815.1
# 6 1                        596.17463             292384.5
#   Energy_Consumption_MWh Energy_Storage_Capacity_MWh
# 1 248708.5               2953.249
# 2 166104.2               5305.174
# 3 424114.6               2620.193
# 4 308337.7               1925.250
# 5 360437.8               3948.945
# 6 415449.6               9767.234
#   Storage_Efficiency_Percentage Grid_Integration_Level Initial_Investment_USD
# 1 89.88756                      4                      473224764
# 2 84.40334                      4                      167069722
# 3 60.49825                      2                       84636100
# 4 86.89786                      3                      396768982
# 5 70.94935                      2                       35744128
# 6 50.90191                      3                      449150518
#   Funding_Sources Financial_Incentives_USD GHG_Emission_Reduction_tCO2e
# 1 1                9207772                  6663.817
# 2 2                1685101                 30656.050
# 3 2                5111813                  1749.614
# 4 2                4805902                 43233.238
# 5 1               16686014                 14858.663
# 6 2               11315379                 16089.626
#   Air_Pollution_Reduction_Index Jobs_Created
# 1 81.742461                     1366
# 2 78.139042                     1743
# 3  8.461296                      363
# 4  8.402441                     2821
# 5 28.822867                     2583
# 6  9.038487                      309

# %%
names(energy_data)
# Out:
#  [1] "Type_of_Renewable_Energy"      "Installed_Capacity_MW"
#  [3] "Energy_Production_MWh"         "Energy_Consumption_MWh"
#  [5] "Energy_Storage_Capacity_MWh"   "Storage_Efficiency_Percentage"
#  [7] "Grid_Integration_Level"        "Initial_Investment_USD"
#  [9] "Funding_Sources"               "Financial_Incentives_USD"
# [11] "GHG_Emission_Reduction_tCO2e"  "Air_Pollution_Reduction_Index"
# [13] "Jobs_Created"

# %%
dim(energy_data)
# Out:
# [1] 15000    13

# %%
fit_simple <- lm(energy_data$Installed_Capacity_MW ~ energy_data$Energy_Production_MWh)
fit_simple <- lm(Installed_Capacity_MW ~ Energy_Production_MWh, data = energy_data)

# %%
class(fit_simple)
is.list(fit_simple)
names(fit_simple)
# Out:
# [1] "lm"
# [1] TRUE
#  [1] "coefficients"  "residuals"     "effects"       "rank"
#  [5] "fitted.values" "assign"        "qr"            "df.residual"
#  [9] "xlevels"       "call"          "terms"         "model"

# %%
fit_simple$coefficients
coef(fit_simple)
# Out:
#           (Intercept) Energy_Production_MWh
#          5.016706e+02         -2.304288e-05
#           (Intercept) Energy_Production_MWh
#          5.016706e+02         -2.304288e-05

# %%
?summary.lm
summary(fit_simple)
# Out:
# Call:
# lm(formula = Installed_Capacity_MW ~ Energy_Production_MWh, data = energy_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -499.26 -249.59   -3.11  245.87  508.59
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)            5.017e+02  4.747e+00 105.693   <2e-16 ***
# Energy_Production_MWh -2.304e-05  1.633e-05  -1.411    0.158
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 288.2 on 14998 degrees of freedom
# Multiple R-squared:  0.0001327,	Adjusted R-squared:  6.6e-05
# F-statistic:  1.99 on 1 and 14998 DF,  p-value: 0.1584
# summary.lm                package:stats                R Documentation
#
# s
#
# n:
#
#      ‘summary’ method for class ‘"lm"’.
#
# e:
#
#      ## S3 method for class 'lm'
#      summary(object, correlation = FALSE, symbolic.cor = FALSE, ...)
#
#      ## S3 method for class 'summary.lm'
#      print(x, digits = max(3, getOption("digits") - 3),
#            symbolic.cor = x$symbolic.cor,
#            signif.stars = getOption("show.signif.stars"), ...)
#
# s:
#
#   object: an object of class ‘"lm"’, usually, a result of a call to
#           ‘lm’.
#
#        x: an object of class ‘"summary.lm"’, usually, a result of a
#           call to ‘summary.lm’.
#
# correlation: logical; if ‘TRUE’, the correlation matrix of the
#           estimated parameters is returned and printed.
#
#   digits: the number of significant digits to use when printing.
#
# symbolic.cor: logical. If ‘TRUE’, print the correlations in a symbolic
#           form (see ‘symnum’) rather than as numbers.
#
# signif.stars: logical. If ‘TRUE’, ‘significance stars’ are printed for
#           each coefficient.
#
#      ...: further arguments passed to or from other methods.
#
# s:
#
#      ‘print.summary.lm’ tries to be smart about formatting the
#      coefficients, standard errors, etc. and additionally gives
#      ‘significance stars’ if ‘signif.stars’ is ‘TRUE’.
#
#      Aliased coefficients are omitted in the returned object but
#      restored by the ‘print’ method.
#
#      Correlations are printed to two decimal places (or symbolically):
#      to see the actual correlations print ‘summary(object)$correlation’
#      directly.
#
# e:
#
#      The function ‘summary.lm’ computes and returns a list of summary
#      statistics of the fitted linear model given in ‘object’, using the
#      components (list elements) ‘"call"’ and ‘"terms"’ from its
#      argument, plus
#
# residuals: the _weighted_ residuals, the usual residuals rescaled by
#           the square root of the weights specified in the call to ‘lm’.
#
# coefficients: a p x 4 matrix with columns for the estimated
#           coefficient, its standard error, t-statistic and
#           corresponding (two-sided) p-value.  Aliased coefficients are
#           omitted.
#
#  aliased: named logical vector showing if the original coefficients are
#           aliased.
#
#    sigma: the square root of the estimated variance of the random error
#
#                        sigma^2 = 1/(n-p) Sum(w[i] R[i]^2),
#
#           where R[i] is the i-th residual, ‘residuals[i]’.
#
#       df: degrees of freedom, a 3-vector (p, n-p, p*), the first being
#           the number of non-aliased coefficients, the last being the
#           total number of coefficients.
#
# fstatistic: (for models including non-intercept terms) a 3-vector with
#           the value of the F-statistic with its numerator and
#           denominator degrees of freedom.
#
# r.squared: R^2, the ‘fraction of variance explained by the model’,
#
#                     R^2 = 1 - Sum(R[i]^2) / Sum((y[i]- y*)^2),
#
#           where y* is the mean of y[i] if there is an intercept and
#           zero otherwise.
#
# adj.r.squared: the above R^2 statistic ‘_adjusted_’, penalizing for
#           higher p.
#
# cov.unscaled: a p x p matrix of (unscaled) covariances of the coef[j],
#           j=1, ..., p.
#
# correlation: the correlation matrix corresponding to the above
#           ‘cov.unscaled’, if ‘correlation = TRUE’ is specified.
#
# symbolic.cor: (only if ‘correlation’ is true.)  The value of the
#           argument ‘symbolic.cor’.
#
# na.action: from ‘object’, if present there.
#
# o:
#
#      The model fitting function ‘lm’, ‘summary’.
#
#      Function ‘coef’ will extract the matrix of coefficients with
#      standard errors, t-statistics and p-values.
#
# s:
#
#      ##-- Continuing the  lm(.) example:
#      coef(lm.D90)  # the bare coefficients
#      sld90 <- summary(lm.D90 <- lm(weight ~ group -1))  # omitting intercept
#      sld90
#      coef(sld90)  # much more
#
#      ## model with *aliased* coefficient:
#      lm.D9. <- lm(weight ~ group + I(group != "Ctl"))
#      Sm.D9. <- summary(lm.D9.)
#      Sm.D9. #  shows the NA NA NA NA  line
#      stopifnot(length(cc <- coef(lm.D9.)) == 3, is.na(cc[3]),
#                dim(coef(Sm.D9.)) == c(2,4), Sm.D9.$df == c(2, 18, 3))

# %%
summaryList <- summary(fit_simple)
summaryList$sigma
summaryList$r.squared
summaryList$fstatistic
# Out:
# [1] 288.2034
# [1] 0.0001326634
#       value       numdf       dendf
#     1.98995     1.00000 14998.00000

# %%
confint(fit_simple)
# Out:
#                       2.5 %         97.5 %
# (Intercept)            4.923669e+02 5.109744e+02
# Energy_Production_MWh -5.506122e-05 8.975462e-06

# %%
# predict(fit_simple, data.frame(lstat = c(5, 10, 15)), interval = "confidence")

# %%
# DODAJ PREDICTY - TUTAJ TRZEBA PODZIAŁAĆ Z BIBLIOTEKĄ

# %%
plot(energy_data$Installed_Capacity_MW, energy_data$Energy_Production_MWh)
abline(fit_simple)
# Out:
# plot without title

# %%
plot(fit_simple)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
plot(predict(fit_simple), residuals(fit_simple))
plot(predict(fit_simple), rstudent(fit_simple))
# Out:
# plot without title
# plot without title

# %%
plot(hatvalues(fit_simple))
which.max(hatvalues(fit_simple))
# Out:
# 2273
# 2273
# plot without title

# %% [markdown]
# Regresja wielokrotna

# %%
fit_la <- lm(energy_data$Installed_Capacity_MW ~ energy_data$Energy_Production_MWh + energy_data$Energy_Consumption_MWh)
summary(fit_la)
# Out:
# Call:
# lm(formula = energy_data$Installed_Capacity_MW ~ energy_data$Energy_Production_MWh +
#     energy_data$Energy_Consumption_MWh)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -500.04 -249.27   -2.87  246.00  509.45
#
# Coefficients:
#                                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)                         4.983e+02  6.283e+00  79.310   <2e-16 ***
# energy_data$Energy_Production_MWh  -2.304e-05  1.634e-05  -1.410    0.158
# energy_data$Energy_Consumption_MWh  1.483e-05  1.821e-05   0.814    0.416
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 288.2 on 14997 degrees of freedom
# Multiple R-squared:  0.0001769,	Adjusted R-squared:  4.353e-05
# F-statistic: 1.326 on 2 and 14997 DF,  p-value: 0.2654

# %%
numerical_data <- energy_data[, sapply(energy_data, is.numeric)]

fit_all <- lm(Installed_Capacity_MW ~ ., data = numerical_data)
summary(fit_all)
# Out:
# Call:
# lm(formula = Installed_Capacity_MW ~ ., data = numerical_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -513.26 -250.45   -2.68  246.37  521.79
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                    4.935e+02  1.924e+01  25.655   <2e-16 ***
# Type_of_Renewable_Energy      -1.198e-01  1.177e+00  -0.102   0.9190
# Energy_Production_MWh         -2.297e-05  1.634e-05  -1.406   0.1597
# Energy_Consumption_MWh         1.478e-05  1.822e-05   0.811   0.4172
# Energy_Storage_Capacity_MWh    1.126e-03  8.134e-04   1.385   0.1661
# Storage_Efficiency_Percentage  7.905e-03  1.625e-01   0.049   0.9612
# Grid_Integration_Level        -2.733e+00  2.096e+00  -1.304   0.1922
# Initial_Investment_USD         1.330e-08  1.643e-08   0.809   0.4184
# Funding_Sources               -7.773e-01  2.880e+00  -0.270   0.7872
# Financial_Incentives_USD       1.514e-07  4.068e-07   0.372   0.7097
# GHG_Emission_Reduction_tCO2e   2.746e-04  1.637e-04   1.677   0.0935 .
# Air_Pollution_Reduction_Index -7.411e-02  8.243e-02  -0.899   0.3686
# Jobs_Created                  -2.627e-04  1.622e-03  -0.162   0.8714
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 288.2 on 14987 degrees of freedom
# Multiple R-squared:  0.0007257,	Adjusted R-squared:  -7.441e-05
# F-statistic: 0.907 on 12 and 14987 DF,  p-value: 0.5389

# %%
fit_no_grid_int <- update(fit_all, ~ . - Grid_Integration_Level)
summary(fit_no_grid_int)
# Out:
# Call:
# lm(formula = Installed_Capacity_MW ~ Type_of_Renewable_Energy +
#     Energy_Production_MWh + Energy_Consumption_MWh + Energy_Storage_Capacity_MWh +
#     Storage_Efficiency_Percentage + Initial_Investment_USD +
#     Funding_Sources + Financial_Incentives_USD + GHG_Emission_Reduction_tCO2e +
#     Air_Pollution_Reduction_Index + Jobs_Created, data = numerical_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -511.77 -250.08   -2.43  246.54  517.74
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                    4.870e+02  1.857e+01  26.227   <2e-16 ***
# Type_of_Renewable_Energy      -1.104e-01  1.177e+00  -0.094   0.9253
# Energy_Production_MWh         -2.292e-05  1.634e-05  -1.403   0.1607
# Energy_Consumption_MWh         1.485e-05  1.822e-05   0.815   0.4150
# Energy_Storage_Capacity_MWh    1.135e-03  8.134e-04   1.395   0.1630
# Storage_Efficiency_Percentage  3.829e-03  1.625e-01   0.024   0.9812
# Initial_Investment_USD         1.333e-08  1.643e-08   0.811   0.4172
# Funding_Sources               -8.103e-01  2.879e+00  -0.281   0.7784
# Financial_Incentives_USD       1.525e-07  4.068e-07   0.375   0.7077
# GHG_Emission_Reduction_tCO2e   2.746e-04  1.637e-04   1.677   0.0936 .
# Air_Pollution_Reduction_Index -7.458e-02  8.243e-02  -0.905   0.3656
# Jobs_Created                  -2.637e-04  1.622e-03  -0.163   0.8709
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 288.2 on 14988 degrees of freedom
# Multiple R-squared:  0.0006123,	Adjusted R-squared:  -0.0001212
# F-statistic: 0.8348 on 11 and 14988 DF,  p-value: 0.605

# %%
plot(ellipse(fit_la, which = -1), type = "l")
la_coefs <- coef(fit_la)
points(la_coefs[2], la_coefs[3])

# %%
summary(lm(energy_data$Installed_Capacity_MW ~ energy_data$Energy_Production_MWh * energy_data$Energy_Consumption_MWh))
# Out:
# Call:
# lm(formula = energy_data$Installed_Capacity_MW ~ energy_data$Energy_Production_MWh *
#     energy_data$Energy_Consumption_MWh)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -498.78 -249.39   -2.91  246.60  511.26
#
# Coefficients:
#                                                                        Estimate
# (Intercept)                                                           5.051e+02
# energy_data$Energy_Production_MWh                                    -4.987e-05
# energy_data$Energy_Consumption_MWh                                   -1.513e-05
# energy_data$Energy_Production_MWh:energy_data$Energy_Consumption_MWh  1.188e-10
#                                                                      Std. Error
# (Intercept)                                                           9.566e+00
# energy_data$Energy_Production_MWh                                     3.294e-05
# energy_data$Energy_Consumption_MWh                                    3.677e-05
# energy_data$Energy_Production_MWh:energy_data$Energy_Consumption_MWh  1.267e-10
#                                                                      t value
# (Intercept)                                                           52.798
# energy_data$Energy_Production_MWh                                     -1.514
# energy_data$Energy_Consumption_MWh                                    -0.411
# energy_data$Energy_Production_MWh:energy_data$Energy_Consumption_MWh   0.938
#                                                                      Pr(>|t|)
# (Intercept)                                                            <2e-16
# energy_data$Energy_Production_MWh                                       0.130
# energy_data$Energy_Consumption_MWh                                      0.681
# energy_data$Energy_Production_MWh:energy_data$Energy_Consumption_MWh    0.348
#
# (Intercept)                                                          ***
# energy_data$Energy_Production_MWh
# energy_data$Energy_Consumption_MWh
# energy_data$Energy_Production_MWh:energy_data$Energy_Consumption_MWh
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 288.2 on 14996 degrees of freedom
# Multiple R-squared:  0.0002355,	Adjusted R-squared:  3.55e-05
# F-statistic: 1.177 on 3 and 14996 DF,  p-value: 0.3166

# %%
fit_l2 <- lm(energy_data$Installed_Capacity_MW ~ energy_data$Energy_Production_MWh + I(energy_data$Energy_Consumption_MWh^2))
summary(fit_l2)
# Out:
# Call:
# lm(formula = energy_data$Installed_Capacity_MW ~ energy_data$Energy_Production_MWh +
#     I(energy_data$Energy_Consumption_MWh^2))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -500.19 -249.26   -2.84  246.03  509.83
#
# Coefficients:
#                                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)                              4.995e+02  5.434e+00  91.928   <2e-16
# energy_data$Energy_Production_MWh       -2.303e-05  1.634e-05  -1.410    0.159
# I(energy_data$Energy_Consumption_MWh^2)  3.146e-11  3.899e-11   0.807    0.420
#
# (Intercept)                             ***
# energy_data$Energy_Production_MWh
# I(energy_data$Energy_Consumption_MWh^2)
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 288.2 on 14997 degrees of freedom
# Multiple R-squared:  0.0001761,	Adjusted R-squared:  4.272e-05
# F-statistic:  1.32 on 2 and 14997 DF,  p-value: 0.2671

# %%
anova(fit_simple, fit_l2)
# Out:
# Warning message in anova.lmlist(object, ...):
# “models with response ‘"energy_data$Installed_Capacity_MW"’ removed because response differs from model 1”
#                       Df    Sum Sq       Mean Sq   F value Pr(>F)
# Energy_Production_MWh     1     165287.6 165287.57 1.98995 0.1583669
# Residuals             14998 1245751542.0  83061.18      NA        NA

# %%
fit_l5 <- lm(energy_data$Energy_Consumption_MWh ~ poly(energy_data$Energy_Production_MWh, 5))
summary(fit_l5)
# Out:
# Call:
# lm(formula = energy_data$Energy_Consumption_MWh ~ poly(energy_data$Energy_Production_MWh,
#     5))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -237676 -110682    -823  112352  228981
#
# Coefficients:
#                                             Estimate Std. Error t value
# (Intercept)                                   225982       1055 214.205
# poly(energy_data$Energy_Production_MWh, 5)1    -5927     129208  -0.046
# poly(energy_data$Energy_Production_MWh, 5)2   -22949     129208  -0.178
# poly(energy_data$Energy_Production_MWh, 5)3    44926     129208   0.348
# poly(energy_data$Energy_Production_MWh, 5)4   295308     129208   2.286
# poly(energy_data$Energy_Production_MWh, 5)5   232817     129208   1.802
#                                             Pr(>|t|)
# (Intercept)                                   <2e-16 ***
# poly(energy_data$Energy_Production_MWh, 5)1   0.9634
# poly(energy_data$Energy_Production_MWh, 5)2   0.8590
# poly(energy_data$Energy_Production_MWh, 5)3   0.7281
# poly(energy_data$Energy_Production_MWh, 5)4   0.0223 *
# poly(energy_data$Energy_Production_MWh, 5)5   0.0716 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 129200 on 14994 degrees of freedom
# Multiple R-squared:  0.0005749,	Adjusted R-squared:  0.0002416
# F-statistic: 1.725 on 5 and 14994 DF,  p-value: 0.1251

# %%
summary(lm(Energy_Production_MWh ~ log(Energy_Consumption_MWh), data = energy_data))
# Out:
# Call:
# lm(formula = Energy_Production_MWh ~ log(Energy_Consumption_MWh),
#     data = energy_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -251312 -123825     880  124686  247686
#
# Coefficients:
#                              Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 251605.51   14847.18   16.95   <2e-16 ***
# log(Energy_Consumption_MWh)     61.94    1229.72    0.05     0.96
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 144100 on 14998 degrees of freedom
# Multiple R-squared:  1.691e-07,	Adjusted R-squared:  -6.651e-05
# F-statistic: 0.002537 on 1 and 14998 DF,  p-value: 0.9598
